# %%
import json
import os
from pathlib import Path
from google.colab import drive

# %%
drive.mount('/content/drive', force_remount=True)
pathToDataset = "drive/MyDrive/pubmed-dataset"
pathToExport = "drive/MyDrive/chunking-dataset"
# Out:
# Mounted at /content/drive

# %%
def save_articles(articles, output_folder, dataset_type, file_count):
    file_name = f'{dataset_type}_part-{file_count}.json'
    output_path = os.path.join(output_folder, file_name)
    with open(output_path, 'w') as outfile:
        json.dump(articles, outfile)
    print(f'File {output_path} created with {len(articles)} articles')

def split_file(input_file, output_base_folder, dataset_type, articles_per_file, max_files=10):
    output_folder = Path(output_base_folder) / dataset_type
    output_folder.mkdir(parents=True, exist_ok=True)

    articles = []
    file_count = 0

    with open(input_file, 'r') as file:
        for line in file:
            if file_count >= max_files:
                break

            try:
                article = json.loads(line)
                articles.append(article)

                if len(articles) == articles_per_file:
                    save_articles(articles, output_folder, dataset_type, file_count)
                    articles = []
                    file_count += 1

            except json.JSONDecodeError as e:
                print(f"Error decoding JSON in file {input_file}, line: {line}")
                print(f"Error message: {e}")

    if articles and file_count < max_files:
        save_articles(articles, output_folder, dataset_type, file_count)

# Utilisation de la fonction
base_path = Path(pathToDataset)
output_base = Path(pathToExport)

split_file(base_path / "test.txt", output_base, "test", 1000, 7)
split_file(base_path / "train.txt", output_base, "train", 1000, 500)
split_file(base_path / "val.txt", output_base, "val", 1000, 7)
# Out:
# File drive/MyDrive/chunking-dataset/test/test_part-0.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/test/test_part-1.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/test/test_part-2.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/test/test_part-3.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/test/test_part-4.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/test/test_part-5.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/test/test_part-6.json created with 658 articles
# File drive/MyDrive/chunking-dataset/train/train_part-0.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-1.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-2.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-3.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-4.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-5.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-6.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-7.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-8.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-9.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-10.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-11.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-12.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-13.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-14.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-15.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-16.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-17.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-18.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-19.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-20.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-21.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-22.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-23.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-24.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-25.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-26.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-27.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-28.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-29.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-30.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-31.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-32.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-33.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-34.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-35.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-36.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-37.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-38.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-39.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-40.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-41.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-42.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-43.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-44.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-45.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-46.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-47.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-48.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-49.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-50.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-51.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-52.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-53.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-54.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-55.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-56.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-57.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-58.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-59.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-60.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-61.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-62.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-63.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-64.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-65.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-66.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-67.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-68.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-69.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-70.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-71.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-72.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-73.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-74.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-75.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-76.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-77.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-78.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-79.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-80.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-81.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-82.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-83.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-84.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-85.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-86.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-87.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-88.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-89.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-90.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-91.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-92.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-93.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-94.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-95.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-96.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-97.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-98.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-99.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-100.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-101.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-102.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-103.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-104.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-105.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-106.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-107.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-108.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-109.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-110.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-111.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-112.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-113.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-114.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-115.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-116.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-117.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-118.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/train/train_part-119.json created with 924 articles
# File drive/MyDrive/chunking-dataset/val/val_part-0.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/val/val_part-1.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/val/val_part-2.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/val/val_part-3.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/val/val_part-4.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/val/val_part-5.json created with 1000 articles
# File drive/MyDrive/chunking-dataset/val/val_part-6.json created with 633 articles
